# %% [markdown]
# # Analisis y gestión de nulos de las columnas categóricas

# %%
# Importaciones

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append("..")
from src import sp_eda, sp_visualizacion

# %%
# Leer el archivo de datos_limpios.xlsx
df_limpio= pd.read_excel('../data/datos_limpios.xlsx')
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74990 entries, 0 to 74989
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoiceno       74990 non-null  object
#  1   customerid      46815 non-null  float64
#  2   region          74990 non-null  object
#  3   country         74990 non-null  object
#  4   item_type       74990 non-null  object
#  5   sales_channel   74990 non-null  object
#  6   order_priority  74990 non-null  object
#  7   order_date      74990 non-null  datetime64[ns]
#  8   order_id        74990 non-null  int64
#  9   ship_date       74990 non-null  datetime64[ns]
#  10  units_sold      74990 non-null  int64
#  11  unit_price      74990 non-null  int64
#  12  unit_cost       74990 non-null  int64
#  13  total_revenue   74990 non-null  int64
#  14  total_cost      74990 non-null  int64
#  15  total_profit    74990 non-null  int64
#  16  ship_year       74990 non-null  int64
# ...

# %% [markdown]
# ## Observación general de nulos

# %%
numero_nulos_df_limpio, porcentaje_nulos_df_limpio = sp_eda.calcular_nulos(df_limpio)

# %% [markdown]
# ## Análisis y gestión de las columnas categoricas

# %%
# Seleccionamos las columnas categoricas
col_categoricas = df_limpio.select_dtypes(include=['object']).columns
col_categoricas
# Out:
# Index(['invoiceno', 'region', 'country', 'item_type', 'sales_channel',
#        'order_priority', 'ship_day'],
#       dtype='object')

# %%
# Analisis de todas las columnas categoricas
sp_eda.analisis_general_cat(df_limpio)
# Out:
# La dsitribución de las columna INVOICENO
# Esta columna tiene 3335 valores únicos
# invoiceno
# 537434    0.009001
# 538071    0.008694
# 538349    0.008268
# 537638    0.008014
# 537237    0.007961
#             ...
# 538047    0.000013
# 538046    0.000013
# 538045    0.000013
# 538043    0.000013
# 541043    0.000013
# Name: proportion, Length: 3335, dtype: float64
# -----------
# count      74990
# unique      3335
# top       537434
# freq         675
# Name: invoiceno, dtype: object
# -----------
# La dsitribución de las columna REGION
# Esta columna tiene 7 valores únicos
# region
# sub-saharan africa                   0.260661
# europe                               0.257981
# asia                                 0.144739
# middle east and north africa         0.125497
# central america and the caribbean    0.107721
# australia and oceania                0.081811
# north america                        0.021590
# Name: proportion, dtype: float64
# -----------
# ...

# %%
# Vemos subplots de las columnas categoricas
sp_visualizacion.subplot_col_cat(df_limpio)

# %% [markdown]
# ## Gestión de nulos de las categoricas

# %%
df_cat = df_limpio[df_limpio.select_dtypes(include=['object']).columns]
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74990 entries, 0 to 74989
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoiceno       74990 non-null  object
#  1   region          74990 non-null  object
#  2   country         74990 non-null  object
#  3   item_type       74990 non-null  object
#  4   sales_channel   74990 non-null  object
#  5   order_priority  74990 non-null  object
#  6   ship_day        74990 non-null  object
# dtypes: object(7)
# memory usage: 4.0+ MB

# %%
sp_eda.calcular_nulos(df_cat)[1]
# Out:
# invoiceno         0.0
# region            0.0
# country           0.0
# item_type         0.0
# sales_channel     0.0
# order_priority    0.0
# ship_day          0.0
# dtype: float64

# %% [markdown]
# En las columnas categoricas no hay nulos.
